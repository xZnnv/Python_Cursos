# %% [markdown]
# <a href="https://colab.research.google.com/github/xZnnv/Python_Cursos/blob/main/Notebooks/Trabajo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
